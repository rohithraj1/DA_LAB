# %%
import urllib2
import csv

with open ('MovieGenre.csv') as images:
    images = csv.reader(images)
    img_count = 1
    for image in images:
        urlretrieve(image[0],
                'images/image_{0}.jpg'.format(img_count)) 
        img_count += 1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-45553ad8f1c8> in <module>()
# ----> 1 import urllib2
#       2 import csv
#       3
#       4 with open ('MovieGenre.csv') as images:
#       5     images = csv.reader(images)
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import urllib2
import csv

with open ('MovieGenre.csv') as images:
    images = csv.reader(images)
    img_count = 1
    for image in images:
        urlretrieve(image[0],
                'images/image_{0}.jpg'.format(img_count)) 
        img_count += 1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-45553ad8f1c8> in <module>()
# ----> 1 import urllib2
#       2 import csv
#       3
#       4 with open ('MovieGenre.csv') as images:
#       5     images = csv.reader(images)
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import urllib.request
import pandas as pd
import os
df1=pd.read_csv("MovieGenre.csv",encoding="latin1")
posters = df1.Poster
genre = df1.Genre
for i in range(len(posters)):
    print (i)
    if "|" in str(genre[i]):
        list1=str1.split("|")
        str1=list1[0]
    else:
        str1=str(genre[i])
    print (str1)
    if "https://" in str(posters[i]):
        try:
            url="c:/new folder/"
            url=url+str1
            if not os.path.exists(url):
                os.makedirs(url)
            urllib.request.urlretrieve(posters[i],"c:/new folder/"+str1+"/"+str(i)+".jpg")
            
        except IOError:
            print ("Error: can\'t find file or read data")
            continue
# Out:
# 0
# Comedy
# 1
# Comedy
# 2
# Comedy
# 3
# Comedy
# 4
# Comedy
# 5
# Comedy
# 6
# Comedy
# 7
# Comedy
# Error: can't find file or read data
# 8
# Comedy
# 9
# Comedy
# 10
# Comedy
# 11
# Comedy
# 12
# Comedy
# 13
# Comedy
# 14
# Comedy
# 15
# Comedy
# 16
# Comedy
# 17
# Comedy
# 18
# Comedy
# 19
# Comedy
# 20
# Comedy
# 21
# Comedy
# 22
# Comedy
# 23
# Comedy
# 24
# Comedy
# 25
# Comedy
# 26
# Comedy
# 27
# Drama
# 28
# Drama
# 29
# Drama
# 30
# Drama
# 31
# Drama
# 32
# Drama
# 33
# Drama
# 34
# Drama
# 35
# Drama
# 36
# Drama
# 37
# Drama
# 38
# Drama
# 39
# Drama
# 40
# Drama
# 41
# Drama
# 42
# Drama
# 43
# Drama
# 44
# Drama
# 45
# Drama
# 46
# Drama
# 47
# Drama
# 48
# Drama
# 49
# Drama
# 50
# Drama
# Error: can't find file or read data
# 51
# Drama
# 52
# Drama
# 53
# Drama
# Error: can't find file or read data
# 54
# Drama
# 55
# Drama
# 56
# Drama
# 57
# Drama
# 58
# Drama
# 59
# Drama
# 60
# Drama
# 61
# Drama
# 62
# Drama
# 63
# Drama
# 64
# Comedy
# 65
# Comedy
# 66
# ...
